# %%
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt

dataset = pd.read_csv("../../Datasets/ISOT Botnet 2010/Pre-processed/isot_botnet.csv", index_col=0)

print(dataset.head())

# create color dictionary
colors = {'Botnet':'r', 'Normal':'g'}

#

# create a figure and axis
fig, ax = plt.subplots(figsize = (12,12))

# plot each data-point
#for i in range(1, 80000, 10):
#    ax.scatter(dataset['Dur'][i], dataset['TotPkts'][i], color=colors[dataset['Label'][i]])

ax.scatter(dataset['Dur'], dataset['TotPkts'], c=colors[dataset['Label']])

# set a title and labels
ax.set_title('ISOT Dataset')
#ax.set_xlabel('Dur')
#ax.set_ylabel('TotPkts')

plt.show()

del dataset
# Out:
#          StartTime       Dur Proto      SrcAddr  Sport    Dir         DstAddr  \
# 0  23:05:38.958596  2.925192   tcp  172.16.0.12   1035     ->  198.155.242.22
# 1  23:05:38.959924  0.920834   tcp  172.16.0.12   1036     ->    64.95.58.150
# 2  23:05:47.893319  0.000000   tcp  172.16.0.12   1035     ->  198.155.242.22
# 3  23:05:59.619627  0.347173   tcp  172.16.0.12   1036     ->    64.95.58.150
# 4  23:05:59.970500  1.143746   tcp  172.16.0.12   1038     ->      89.3.63.62
#
#    Dport State  sTos  dTos  TotPkts  TotBytes  SrcBytes   Label
# 0     80   REQ   0.0   0.0        2       124       124  Botnet
# 1     80   CON   0.0   0.0       14      8924      4599  Botnet
# 2     80   REQ   0.0   0.0        1        62        62  Botnet
# 3     80   RST   0.0   0.0        3       174       120  Botnet
# 4     80   CON   0.0   0.0        8      2152      1439  Botnet
# ---------------------------------------------------------------------------
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv("../../Datasets/ISOT Botnet 2010/Pre-processed/isot_botnet.csv", index_col=0)

print(dataset.shape[0])
# Out:
# 336771

# %%
#
# t-SNE test
#

# Imports
# %run ../Dataset_Preprocessing_ISOT/isot_preprocessor.py

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE


# Main function
# Get dataset
dataset = pd.read_csv("../../Datasets/ISOT Botnet 2010/Pre-processed/isot_botnet.csv", index_col=0)

y = dataset['Label']

print(dataset.head())
X = dataset.drop(['StartTime', 'Proto', 'SrcAddr', 'Sport', 'DstAddr', 'Dport', 'Dir', 'State', 'Label'], axis=1)
print(dataset.head())

# PCA
pca = PCA(n_components=2)
X = pca.fit_transform(X)

print(pca.explained_variance_ratio_)

X = pd.DataFrame(data = X, columns = ['principal component 1', 'principal component 2'])
finalDf = pd.concat([X, y], axis=1)

fig = plt.figure(figsize = (12,12))
ax = fig.add_subplot(1,1,1) 

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Normal', 'Botnet']
colors = ['g', 'r']

for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Label'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 100)
ax.legend(targets)
ax.grid()
    
# Setup t-sne
#tsne = TSNE(n_components=2, random_state=0)
#X = tsne.fit_transform(dataset)

#plt.scatter(X)

# Delete preprocessor object
del dataset
# Out:
#          StartTime       Dur Proto      SrcAddr  Sport    Dir         DstAddr  \
# 0  23:05:38.958596  2.925192   tcp  172.16.0.12   1035     ->  198.155.242.22
# 1  23:05:38.959924  0.920834   tcp  172.16.0.12   1036     ->    64.95.58.150
# 2  23:05:47.893319  0.000000   tcp  172.16.0.12   1035     ->  198.155.242.22
# 3  23:05:59.619627  0.347173   tcp  172.16.0.12   1036     ->    64.95.58.150
# 4  23:05:59.970500  1.143746   tcp  172.16.0.12   1038     ->      89.3.63.62
#
#    Dport State  sTos  dTos  TotPkts  TotBytes  SrcBytes   Label
# 0     80   REQ   0.0   0.0        2       124       124  Botnet
# 1     80   CON   0.0   0.0       14      8924      4599  Botnet
# 2     80   REQ   0.0   0.0        1        62        62  Botnet
# 3     80   RST   0.0   0.0        3       174       120  Botnet
# 4     80   CON   0.0   0.0        8      2152      1439  Botnet
#          StartTime       Dur Proto      SrcAddr  Sport    Dir         DstAddr  \
# ...
