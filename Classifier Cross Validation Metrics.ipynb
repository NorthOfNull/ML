# %%
# %reload_ext autoreload
# %autoreload 2

# BASE DATASETS
# STRATIFIED 10-FOLD CROSS VALIDATION METRICS - CLASSIFIER COMPARISON CODE
import kf_ml_lib as kf
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import cross_validate

from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC

scoring = ['precision_macro', 'recall_macro']

# Array of Classifiers under test
classifiers = [GaussianNB(),
               DecisionTreeClassifier(),
               RandomForestClassifier(),
               AdaBoostClassifier()
              ]

# For each dataset
for dataset_path in kf.dataset_path_list:
    print("Dataset = ", dataset_path)
    
    # Load and Split Dataset
    dataset = kf.load_dataset(dataset_path)
    X, y = kf.split_dataset(dataset, extended=False)
    del dataset
    
    # Cross Validating each classifier on the given dataset
    for classifier in classifiers:
        # Cross Validate the classifer on the full dataset
        results = cross_validate(classifier, X, y, cv=10, scoring=scoring, n_jobs=8, verbose=0)

        fit_time = np.mean(results['fit_time'])
        precision = np.mean(results['test_precision_macro'])
        recall = np.mean(results['test_recall_macro'])
        f1_score = kf.calc_f1_score(precision, recall)

        print(classifier)
        print("Fit Time = ", fit_time)
        print("Precision = ", precision)
        print("Recall = ", recall)
        print("F1 Score = ", f1_score)
        print("\n")
        
    del X, y
    print("////////////////////////////////////////////////////////////////////////\n\n")
# Out:
# Dataset =  ../Datasets/CTU-13/Pre-processed/1.csv
# c:\users\asmarus\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# GaussianNB(priors=None, var_smoothing=1e-09)
# Fit Time =  6.790435242652893
# Precision =  0.5084126915199924
# Recall =  0.5833813553804225
# F1 Score =  0.5433231403185975
#
#
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
# Fit Time =  24.772272372245787
# Precision =  0.8604743906896261
# ...

# %%
# %reload_ext autoreload
# %autoreload 2

# BASE DATASETS
# STRATIFIED 10-FOLD CROSS VALIDATION METRICS - CLASSIFIER COMPARISON CODE
import kf_ml_lib as kf
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import cross_validate

from sklearn.svm import LinearSVC

scoring = ['precision_macro', 'recall_macro']

classifiers = [LinearSVC()] 

# For each dataset
for dataset_path in kf.dataset_path_list:
    print("Dataset = ", dataset_path)
    
    # Load and Split Dataset
    dataset = kf.load_dataset(dataset_path)
    X, y = kf.split_dataset(dataset, extended=False)
    del dataset
    
    # Cross Validating each classifier on the given dataset
    for classifier in classifiers:
        # Cross Validate the classifer on the full dataset
        results = cross_validate(classifier, X, y, cv=10, scoring=scoring, n_jobs=8, verbose=0)

        fit_time = np.mean(results['fit_time'])
        precision = np.mean(results['test_precision_macro'])
        recall = np.mean(results['test_recall_macro'])
        f1_score = kf.calc_f1_score(precision, recall)

        print(classifier)
        print("Fit Time = ", fit_time)
        print("Precision = ", precision)
        print("Recall = ", recall)
        print("F1 Score = ", f1_score)
        print("\n")
        
    del X, y
    print("////////////////////////////////////////////////////////////////////////\n\n")
# Out:
# Dataset =  ../Datasets/CTU-13/Pre-processed/1.csv
# c:\users\asmarus\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)
# Fit Time =  990.1001078605652
# Precision =  0.49353120193705646
# Recall =  0.4963699107829793
# F1 Score =  0.4949464861211787
#
#
# ////////////////////////////////////////////////////////////////////////
#
#
# Dataset =  ../Datasets/CTU-13/Pre-processed/2.csv
# ...

# %%
# BIO-OPTIMISED CROSS VALIDATION

# %%
# DTC Optimised Hyperparameter CV Test
# %reload_ext autoreload
# %autoreload 2

# BASE DATASETS
# STRATIFIED 10-FOLD CROSS VALIDATION METRICS - CLASSIFIER COMPARISON CODE
import kf_ml_lib as kf
import numpy as np

from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier

scoring = ['precision_macro', 'recall_macro']

# GA DTC Chromosomes
chromosomes = [['gini', 'best', 2, 3, 0.0, None],
               ['entropy', 'best', 3, 3, 0.0, None],
               ['entropy', 'random', 2, 3, 0.0, None],
               ['entropy', 'best', 2, 2, 0.0, None],
               ['entropy', 'best', 3, 3, 0.0, None],
               ['gini', 'best', 4, 3, 0.0, None],
               ['entropy', 'best', 4, 2, 0.02234821215502927, 'balanced'],
               ['gini', 'best', 3, 1, 0.0, 'balanced'],
               ['gini', 'best', 3, 3, 0.0, None],
               ['entropy', 'best', 4, 3, 0.0, None],
               ['entropy', 'best', 2, 1, 0.0, None],
               ['entropy', 'best', 2, 1, 0.0, 'balanced'],
               ['gini', 'best', 2, 1, 0.0, None],
               ['gini', 'best', 2, 1, 0.0, None],
               ['entropy', 'best', 2, 2, 0.0, 'balanced']
              ]

# For each dataset
for chromosome, dataset_path in zip(chromosomes, kf.dataset_path_list):
    print("Dataset = ", dataset_path)
    
    # Load and Split Dataset
    dataset = kf.load_dataset(dataset_path)
    X, y = kf.split_dataset(dataset, extended=False)
    del dataset
    
    # Setup classifier with it's optimised chromosome
    classifier = DecisionTreeClassifier(criterion=chromosome[0],
                                        splitter=chromosome[1],
                                        min_samples_split=chromosome[2],
                                        min_samples_leaf=chromosome[3],
                                        min_weight_fraction_leaf=chromosome[4],
                                        class_weight=chromosome[5])
    
    # Cross Validate the classifer on the full dataset
    results = cross_validate(classifier, X, y, cv=10, scoring=scoring, n_jobs=-1, verbose=0)

    fit_time = np.mean(results['fit_time'])
    precision = np.mean(results['test_precision_macro'])
    recall = np.mean(results['test_recall_macro'])
    f1_score = kf.calc_f1_score(precision, recall)

    print(classifier)
    print("Fit Time = ", fit_time)
    print("Precision = ", precision)
    print("Recall = ", recall)
    print("F1 Score = ", f1_score)
    print("\n")

    del X, y
    print("////////////////////////////////////////////////////////////////////////\n\n")
# Out:
# Dataset =  ../Datasets/CTU-13/Pre-processed/1.csv
# c:\users\asmarus\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
# Fit Time =  29.914845752716065
# Precision =  0.8695471255779286
# Recall =  0.8523520948815875
# F1 Score =  0.8608637547170965
#
#
# ////////////////////////////////////////////////////////////////////////
#
#
# ...

# %%
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt

from sklearn import tree
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import cross_validate, cross_val_predict
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import learning_curve
from sklearn.ensemble import RandomForestClassifier

dataset = kf.load_dataset("../Datasets/ISCX Botnet 2014/Pre-processed/ISCX_Testing.csv")
X, y = kf.split_dataset(dataset)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True)

scoring = ['precision_macro', 'recall_macro']

# Make this an array of classifiers
classifiers = [RandomForestClassifier(n_estimators=100, n_jobs=10),
              RandomForestClassifier(n_estimators=1000, n_jobs=10)]

for classifier in classifiers:
    # Cross Validate the classifer on the full dataset
    cv_results = cross_validate(classifier, X, y, cv=10, scoring=scoring)
    
    # Fit classifier to training dataset
    model = 
    
    # Get mean cv metrics
    metrics.plot_confusion_matrix(classifier, y, y_predicted)
    
    # Plot ROC 


print("Classification report for classifier %s:\n%s\n" % (clf, metrics.classification_report(y_test, predicted)))
disp = metrics.plot_confusion_matrix(clf, X_test, y_test)
disp.figure_.suptitle("Confusion Matrix")
print("Confusion matrix:\n%s" % disp.confusion_matrix)

plt.show()


del dataset, X, y, classifier
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-21-f186c38639b0> in <module>
#      26
#      27     # Get mean cv metrics
# ---> 28     metrics.plot_confusion_matrix(classifier, y, y_predicted)
#      29
#      30     # Plot ROC
#
# c:\users\asmarus\anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py in plot_confusion_matrix(estimator, X, y_true, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax)
#     183         raise ValueError("plot_confusion_matrix only supports classifiers")
#     184
# --> 185     y_pred = estimator.predict(X)
#     186     cm = confusion_matrix(y_true, y_pred, sample_weight=sample_weight,
#     187                           labels=labels, normalize=normalize)
#
# ...

# %%
# %reload_ext autoreload
# %autoreload 2

import kf_ml_lib as kf
import matplotlib.pyplot as plt
import numpy as np

import sklearn.svm as svm
from sklearn import tree
from sklearn import metrics
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier


# 
dataset = kf.load_dataset("../Datasets/ISCX Botnet 2014/Pre-processed/ISCX_Testing.csv")
X, y = kf.split_dataset(dataset)

# Split data into train and test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False)

print(X_train)
print(X_test)
print(y_train)
print(y_test)

# Classifer creation and fitting to the training data
clf = RandomForestClassifier(n_estimators=100)
clf = clf.fit(X_train, y_train)

# Use model to predict test data
predicted = clf.predict(X_test)

print(predicted)

print("Classification report for classifier %s:\n%s\n" % (clf, metrics.classification_report(y_test, predicted)))
disp = metrics.plot_confusion_matrix(clf, X_test, y_test)
disp.figure_.suptitle("Confusion Matrix")
print("Confusion matrix:\n%s" % disp.confusion_matrix)

plt.show()


dtc_disp = plot_roc_curve(clf, X_test, y_test)
plt.show()
# Out:
#               Dur  sTos  dTos  TotPkts  TotBytes  SrcBytes
# 0        0.000000   0.0   0.0        1        60        60
# 1        0.000500   0.0   0.0        2       721       721
# 2        0.000433  16.0   0.0        2      1180      1180
# 3        1.109147   0.0   0.0        3       180       180
# 4        0.000115   0.0   0.0        1       175       175
# ...           ...   ...   ...      ...       ...       ...
# 186864  12.811136   0.0   0.0        2       190       190
# 186865  45.645542  32.0   0.0        3       285       285
# 186866  45.646400   0.0   0.0        3       210       210
# 186867   0.172079   0.0   0.0        2       455        81
# 186868   0.115064   0.0   0.0       24      2671      1773
#
# [186869 rows x 6 columns]
#               Dur  sTos  dTos  TotPkts   TotBytes  SrcBytes
# 186869  58.021137   0.0   0.0        4        380       380
# 186870  58.476936   0.0   0.0        7        423       335
# ...

# %%
# %reload_ext autoreload
# %autoreload 2

import kf_ml_lib as kf
import matplotlib.pyplot as plt
import numpy as np

import sklearn.svm as svm
from sklearn import tree
from sklearn.model_selection import cross_validate


# 
dataset = kf.load_dataset("../Datasets/ISOT Botnet 2010/Pre-processed/isot_botnet.csv")
X, y = kf.split_dataset(dataset)

#y = np.ravel(y)

print(X.head())
print(y)

clf = tree.DecisionTreeClassifier()
metrics = cross_validate(clf, X, y, cv=10, n_jobs=10)

print(sorted(metrics.keys()))

print("")
print(metrics)
print("")
print("Accuracy: %0.2f (+/- %0.2f)" % (metrics['test_score'].mean(), metrics['test_score'].std() * 2))
# Out:
#         Dur  sTos  dTos  TotPkts  TotBytes  SrcBytes
# 0  2.925192   0.0   0.0        2       124       124
# 1  0.920834   0.0   0.0       14      8924      4599
# 2  0.000000   0.0   0.0        1        62        62
# 3  0.347173   0.0   0.0        3       174       120
# 4  1.143746   0.0   0.0        8      2152      1439
# ['Botnet' 'Botnet' 'Botnet' ... 'Normal' 'Normal' 'Normal']
# ['fit_time', 'score_time', 'test_score']
#
# {'fit_time': array([2.60131717, 2.2802608 , 2.65420222, 2.57008386, 2.54116154,
#        2.44222713, 2.49643421, 2.4518199 , 2.54171062, 2.36124468]), 'score_time': array([0.09497952, 0.12798142, 0.08398247, 0.10201144, 0.11305094,
#        0.10801721, 0.09798694, 0.10449815, 0.07573271, 0.13201737]), 'test_score': array([0.86457034, 0.98283695, 0.9869644 , 0.98390593, 0.96899961,
#        0.9792143 , 0.82623155, 0.99364551, 0.98583603, 0.96989043])}
#
# Accuracy: 0.95 (+/- 0.11)

# %%
# %reload_ext autoreload
# %autoreload 2
# Feature Selection
#
# Imports
import pandas as pd
import kf_ml_lib as kf
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.metrics import recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate
from sklearn.metrics import plot_roc_curve
from sklearn import metrics

dataset = kf.load_dataset("../Datasets/ISOT Botnet 2010/Pre-processed/isot_botnet.csv")
X, y = kf.split_dataset(dataset)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=False)

print(x.head())


scoring = ['precision_macro', 'recall_macro']
rfc = RandomForestClassifier()
model = rfc.fit(X_train, y_train)
#scores = cross_validate(clf, x, y, scoring=scoring, cv=2, return_train_score=True)
#sorted(scores.keys())

print(model)

predicitons = model.predict(X_test)
conf_mat = metrics.confusion_matrix(y_test, predictions)
rfc_disp = plot_roc_curve(model, X_test, y_test)


#print(scores)
      
print('')
#print(scores['test_precision_macro'])

del dataset, x, y
# Out:
#          Dur  sTos  dTos  TotPkts  TotBytes  SrcBytes
# id
# 0   2.925192   0.0   0.0        2       124       124
# 1   0.920834   0.0   0.0       14      8924      4599
# 2   0.000000   0.0   0.0        1        62        62
# 3   0.347173   0.0   0.0        3       174       120
# 4   1.143746   0.0   0.0        8      2152      1439
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ---------------------------------------------------------------------------
# ...

# %%
number = 1e-03

print(float(number))
# Out:
# 0.001
