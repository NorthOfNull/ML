# %%
#
# Multiprocessor preprocessing implementation
# 8m minutes multiprocessor vs 20 mins single process
#

# Weird jupyter-notebook behaviour in Windows Anaconda virtual env?
# So this import is required in this way
# In virtual env, 'pip install ipynb'
from ipynb.fs.full.ctu_preprocess_worker import ctu_preprocess_worker, extended_ctu_preprocess_worker

# Imports
import pandas as pd
from multiprocessing import Pool


# Main function
# Run pool processes
# 8 processes in the pool maps to 8 logical processors (CPU)
# Each process uses the same worker function, but different arguments in the range of
# scenario_numbers, used for indexing to the dataset_path_list
# if extended=True; then this will pre-process the extended_dataset_path_list
with Pool(12) as p:
    print("Starting...")
    
    extended = True
    
    if extended:
        p.map(extended_ctu_preprocess_worker, range(1,14))
    else:
        p.map(ctu_preprocess_worker, range(1,14))

print("DONE!!!!!")
# Out:
# Starting...
# ------------------------------------------------------------------
# RemoteTraceback                  Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\users\asmarus\anaconda3\envs\tensorflow-gpu\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "c:\users\asmarus\anaconda3\envs\tensorflow-gpu\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "G:\USB Drive Files\Year 3\Semester 1\KV6003 - Individual Computing Project\Machine Learning\Dataset_Preprocessing_CTU\ctu_preprocess_worker.ipynb", line 73, in extended_ctu_preprocess_worker
#     "    \n",
#   File "G:\USB Drive Files\Year 3\Semester 1\KV6003 - Individual Computing Project\Machine Learning\Dataset_Preprocessing_CTU\ctu_preprocessor.py", line 73, in fix_labels
#     self.dataset.at[row, 'Sport'] = int(src_port, 0)
# ValueError: invalid literal for int() with base 0: '63725.0'
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                       Traceback (most recent call last)
# <ipython-input-8-867c78bf08ed> in <module>
#      26
#      27     if extended:
# ---> 28         p.map(extended_ctu_preprocess_worker, range(1,14))
#      29     else:
#      30         p.map(ctu_preprocess_worker, range(1,14))
#
# c:\users\asmarus\anaconda3\envs\tensorflow-gpu\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# c:\users\asmarus\anaconda3\envs\tensorflow-gpu\lib\multiprocessing\pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# ValueError: invalid literal for int() with base 0: '63725.0'

# %%
from ipynb.fs.full.ctu_preprocess_worker import ctu_preprocess_worker, extended_ctu_preprocess_worker
import pandas as pd

extended_ctu_preprocess_worker(3)
# Out:
# Created preprocessor object
# ../../Datasets/CTU-13/Base_Extended/3.binetflow
# File Read Error
# Started CTU Dataset Netflow Preprocessor!
#      [1/2] Fixing hex values...
#      [2/3] Filling empty fields...
#      [3/3] Fixing labels...
# Finished preprocessing!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed_Extended/3.csv
# File Write Successful!
# Destroying preprocessor object

# %%
#
# Single process = SLOW
# 20 Minutes to process all files
#


# Runs preprocessor class
# %run cty_preprocessor

# Array of paths to each dataset
dataset_path_list = ["../../Datasets/CTU-13/Base/1.binetflow",
                    "../../Datasets/CTU-13/Base/2.binetflow",
                    "../../Datasets/CTU-13/Base/3.binetflow",
                    "../../Datasets/CTU-13/Base/4.binetflow",
                    "../../Datasets/CTU-13/Base/5.binetflow",
                    "../../Datasets/CTU-13/Base/6.binetflow",
                    "../../Datasets/CTU-13/Base/7.binetflow",
                    "../../Datasets/CTU-13/Base/8.binetflow",
                    "../../Datasets/CTU-13/Base/9.binetflow",
                    "../../Datasets/CTU-13/Base/10.binetflow",
                    "../../Datasets/CTU-13/Base/11.binetflow",
                    "../../Datasets/CTU-13/Base/12.binetflow",
                    "../../Datasets/CTU-13/Base/13.binetflow"
                    ]

# Starting scenario number for indexing pre-processed datasets in the
# .csv writing process
scenario_number = 1

# Iterate over each dataset path
for dataset in dataset_path_list:
    # Create a new preprocessor object for each dataset file
    pp = preprocessor(dataset)

    # Load dataset into object's memory; as a Pandas Dataframe
    pp.get_dataset()
    
    # Fix labels
    pp.fix_labels()
    
    # Write dataset with scenario_number
    pp.write_fixed_dataset(scenario_number)

    # Delete preprocessor object
    del pp

    # Iterate scenario_number
    scenario_number += 1
# Out:
# Created preprocessor object
# ../../Datasets/CTU-13/Base/1.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/1.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/2.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/2.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/3.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/3.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/4.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/4.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/5.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/5.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/6.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/6.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/7.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/7.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/8.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/8.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/9.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/9.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/10.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/10.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/11.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/11.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/12.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/12.csv
# File Write Successful!
# Destroying preprocessor object
#
#
# Created preprocessor object
# ../../Datasets/CTU-13/Base/13.binetflow
# Fixing labels...
# Labels fixed!!!
# Writing fixed dataset Dataframe to  ../../Datasets/CTU-13/Pre-processed/13.csv
# File Write Successful!
# Destroying preprocessor object
